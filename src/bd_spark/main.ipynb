# %%
import pandas as pd
import numpy as np
import custom_functions as cf

# %% [markdown]
# # Big Data Managment Lab 03: SPARK
#
#     Dennis Shadrin
#     Matias Borrell

# %%
# Loading the data in pandas just to get an idea of the structure
idealista_df = cf.idealista_loader()
idealista_df.head()
# Out:
# Combined DataFrame created with shape: (21389, 37)
#   propertyCode                                          thumbnail  \
# 0     88841013  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1     93199277  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2     93198927  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3     93155700  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4     92704898  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          W-02I842         22     8  293000.0         flat      sale  80.0
# 1               NaN         24     2  166000.0         flat      sale  63.0
# 2               NaN          5    st   39000.0         flat      sale  50.0
# 3           D-40702         27     4  190000.0         flat      sale  82.0
# 4              3786         37     1  199000.0         flat      sale  71.0
#
#    exterior  ...  priceByArea          detailedType  \
# ...

# %% [markdown]
# ## Data Formatting:

# %% [markdown]
# Using the basic structure that we learned from the dataframe, we proceed to format our data from the landing zone.

# %%
# Data Formatted zone preparation.
# %run A2_script.py
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/06/23 17:53:32 WARN Utils: Your hostname, MacBook-Air-de-Matias.local, resolves to a loopback address: 127.0.0.1; using 172.20.10.9 instead (on interface en0)
# 25/06/23 17:53:32 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/23 17:53:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- bathrooms: long (nullable = true)
#  |-- country: string (nullable = true)
#  |-- detailedType: struct (nullable = true)
# ...

# %% [markdown]
# ## KPIs Creation:
#
# For the idealista dataset, we choosed to create the following KPIs:
#
# 	* Average price per m² per neighborhood
# 	* Average property size by district
# 	* Proportion of properties with elevator by neighborhood
# 	* Total listings per month
# 	* Average number of rooms per district

# %%
# Data Explotation zone preparation / KPIs Calculation
# %run A3_script.py
# Out:
# 25/06/23 17:53:39 WARN MemoryManager: Total allocation exceeds 95,00% (1.020.054.720 bytes) of heap memory
# Scaling row group sizes to 95,00% for 8 writers

# %% [markdown]
# ## Validation:

# %%
# Data Validation and Verification
# %run A4_script.py
# Out:
#  Row count (Formatted Zone): 19900
#  Row count (Exploitation Zone): 19881
#
#  Null counts in Exploitation Zone:
# +--------+------------+-----+----+-----+---------+-------+----------------------+
# |district|neighborhood|price|size|rooms|bathrooms|hasLift|calculatedPricePerArea|
# +--------+------------+-----+----+-----+---------+-------+----------------------+
# |       0|        7622|    0|   0|    0|        0|   2975|                     0|
# +--------+------------+-----+----+-----+---------+-------+----------------------+
#
#
#  Average price per m² by neighborhood:
# +--------------------------------------+----------------+
# |neighborhood                          |avg_price_per_m2|
# +--------------------------------------+----------------+
# |La Dreta de l'Eixample                |6878.62         |
# |Les Tres Torres                       |6371.76         |
# |Pedralbes                             |6331.71         |
# ...
